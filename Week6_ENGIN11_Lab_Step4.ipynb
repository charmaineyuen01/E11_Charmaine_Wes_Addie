# %%
import pandas as pd
import matplotlib.pyplot as plt


indoor = pd.read_csv('lab6_trial1_indoor.csv')

#drop first row bc of calibration
indoor = indoor.iloc[1:].reset_index(drop=True)

# Convert time to seconds since start
indoor["time_seconds"] = indoor["time"] - indoor["time"].iloc[0]

#Remove first 45 seconds of data
indoor_filtered = indoor[indoor["time_seconds"] >= 45]

#df = pd.read_csv('lab6_trial2_outdoor.csv')


plt.figure(figsize=(10, 6))
plt.scatter(indoor_filtered['temp'], indoor_filtered['humidity'], label='Indoor Data' , color='blue', alpha=0.5)



outdoor = pd.read_csv('lab6_trial2_outdoor.csv')
outdoor = outdoor.iloc[1:].reset_index(drop=True)
outdoor["time_seconds"] = outdoor["time"] - outdoor["time"].iloc[0]
outdoor_filtered = outdoor[outdoor["time_seconds"] >= 45]


plt.scatter(outdoor_filtered['temp'], outdoor_filtered['humidity'], label='Outdoor Data' ,color='green', alpha=0.5)


plt.title('Relationship between Humidity and Temperature')
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.grid(True)
plt.legend()
plt.show()

# %%
print(" The hidden data that is not shown in the plot is time; it is important in order to know when the singular dots of the scatterplot were taken.")
# Out:
#  The hidden data that is not shown in the plot is time; it is important in order to know when the singular dots of the scatterplot were taken.

# %%
print("This plot shows that outside, the humidity and temperature follow a somewhat linear relationship over a larger span of both humidity and temperature. Indoors, the data does not have an oberservable pattern or relationship but remains within much narrower bounds.")
# Out:
# This plot shows that outside, the humidity and temperature follow a somewhat linear relationship over a larger span of both humidity and temperature. Indoors, the data does not have an oberservable pattern or relationship but remains within much narrower bounds.

# %%
indoor = pd.read_csv('lab6_trial1_indoor.csv')

#drop first row bc of calibration
indoor = indoor.iloc[1:].reset_index(drop=True)

# Convert time to seconds since start
indoor["time_seconds"] = indoor["time"] - indoor["time"].iloc[0]

#Remove first 45 seconds of data
indoor_filtered = indoor[indoor["time_seconds"] >= 45]

#df = pd.read_csv('lab6_trial2_outdoor.csv')


plt.figure(figsize=(10, 6))
plt.scatter(indoor_filtered['temp'], indoor_filtered['pressure'], label='Indoor Data' , color='blue', alpha=0.5)



outdoor = pd.read_csv('lab6_trial2_outdoor.csv')
outdoor = outdoor.iloc[1:].reset_index(drop=True)
outdoor["time_seconds"] = outdoor["time"] - outdoor["time"].iloc[0]
outdoor_filtered = outdoor[outdoor["time_seconds"] >= 45]


plt.scatter(outdoor_filtered['temp'], outdoor_filtered['pressure'], label='Outdoor Data' ,color='green', alpha=0.5)


plt.title('Relationship between Temperature and Pressure')
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.grid(True)
plt.legend()
plt.show()

# %%
indoor = pd.read_csv('lab6_trial1_indoor.csv')


#drop first row bc of calibration
indoor = indoor.iloc[1:].reset_index(drop=True)

# Convert time to seconds since start
indoor["time_seconds"] = indoor["time"] - indoor["time"].iloc[0]

#Remove first 45 seconds of data
indoor_filtered = indoor[indoor["time_seconds"] >= 45]

#df = pd.read_csv('lab6_trial2_outdoor.csv')


plt.figure(figsize=(10, 6))
plt.scatter(indoor_filtered['temp'], indoor_filtered['pressure'], label='Indoor Data' , color='blue', alpha=0.5)



outdoor = pd.read_csv('lab6_trial2_outdoor.csv')
outdoor = outdoor.iloc[1:].reset_index(drop=True)
outdoor["time_seconds"] = outdoor["time"] - outdoor["time"].iloc[0]
outdoor_filtered = outdoor[outdoor["time_seconds"] >= 45]


plt.scatter(outdoor_filtered['temp'], outdoor_filtered['pressure'], label='Outdoor Data' ,color='green', alpha=0.5)


plt.title('Relationship between Temperature and Pressure')
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.grid(True)
plt.legend()
plt.show()

# %%
import seaborn as sns

sns.pairplot( data = outdoor_filtered )

# %%
print('See the above plots of all data vs all data')
# Out:
# See the above plots of all data vs all data

# %%
indoor = pd.read_csv('lab6_trial1_indoor.csv')


#drop first row bc of calibration
indoor = indoor.iloc[1:].reset_index(drop=True)

# Convert time to seconds since start
indoor["time_seconds"] = indoor["time"] - indoor["time"].iloc[0]

#Remove first 45 seconds of data
indoor_filtered = indoor[indoor["time_seconds"] >= 45]

#df = pd.read_csv('lab6_trial2_outdoor.csv')


plt.figure(figsize=(10, 6))
plt.scatter(indoor_filtered['temp'], indoor_filtered['25um'], label='Indoor Data' , color='blue', alpha=0.5)



outdoor = pd.read_csv('lab6_trial2_outdoor.csv')
outdoor = outdoor.iloc[1:].reset_index(drop=True)
outdoor["time_seconds"] = outdoor["time"] - outdoor["time"].iloc[0]
outdoor_filtered = outdoor[outdoor["time_seconds"] >= 45]


plt.scatter(outdoor_filtered['temp'], outdoor_filtered['25um'], label='Outdoor Data' ,color='green', alpha=0.5)


plt.title('Relationship between Temperature and 25um')
plt.xlabel('Temperature')
plt.ylabel('25um')
plt.grid(True)
plt.legend()
plt.show()

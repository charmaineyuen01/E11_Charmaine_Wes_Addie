# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('lab4data.csv')
df['pm25 standard'].hist(bins=np.arange(-0.5, 2.5, 1) )

plt.title('PM 2.5 Data')
plt.xlabel('Time')
plt.ylabel('Frequency')

plt.show()
